# %%
###DECISIONTREE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
import scipy as sp
# %matplotlib inline
# %config inlinebackend.figure_format="retina"
from matplotlib.font_manager import FontProperties
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
import matplotlib as mpl
import seaborn as sns
from sklearn import tree,metrics
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.datasets import make_classification
import graphviz
import pydotplus
from io import StringIO
from IPython.display import Image

data=pd.read_csv("*:/****/Ternary_Glassformation_dataset.csv")
train,test = train_test_split(data, test_size=0.2)
print(data.shape)
print(train.shape)
print(test.shape)
data_pro=[train,test]
print("data.info：\n",data.info())
print(data.columns.values)
Y1=['GFA']
X1=['a1','a2','a3','Ri1','Ri2','Ri3','E1','E2','E3','Tb1','Tb2','Tb3','Tm1','Tm2','Tm3','ρ1','ρ2','ρ3','Aw1','Aw2','Aw3', 'Rc1','Rc2','Rc3','Ra1','Ra2','Ra3','IE1','IE2','IE3','Eea1','Eea2','Eea3','Ia1','Ia2','Ib1','Ib2','Ic1','Ic2','α1','α2','α3','Cp1','Cp2','Cp3','λ1','λ2','λ3','σ1','σ2','σ3','Hf1','Hf2','Hf3','Hv1','Hv2','Hv3',
'χ1','χ2','χ3','AN1','AN2','AN3','P1','P2','P3','GP1','GP2','GP3','VEC1','VEC2','VEC3','sVEC1','sVEC2','sVEC3','pVEC1','pVEC2','pVEC3','dVEC1','dVEC2','dVEC3','W1','W2','W3','LP1','LP2','LP3','△H12','△H13','△H23']
print(train[Y1].shape)
print(train[X1].shape)
Y2=['GFA']
X2=['Ri','E','Tb','Tm','ρ','Aw', 'Rc','Ra','IE','Eea','I1','I2','α','Cp','λ','σ','Hf','Hv','χ','AN','P','GP','VEC','sVEC','pVEC','dVEC','W','LP','△Hmix','△Sc','δ','VA']
print(train[Y2].shape)
print(train[X2].shape)
Y3=['GFA']
X3=['Ri','E','Tb','Aw','Rc','IE','Eea','α','σ','Hf','GP','sVEC','pVEC','dVEC','LP','△Hmix','△Sc','δ']
print(train[Y3].shape)
print(train[X3].shape)
Y4=['GFA']
X4=['E','ρ','Aw','Eea','α','Cp','λ','σ','Hf','AN','VEC','pVEC','dVEC','LP','△Hmix','△Sc','δ','VA']
print(train[Y4].shape)
print(train[X4].shape)
Y5=['GFA']
X5=['Aw','Eea','α','σ','Hf','pVEC','dVEC','LP','△Hmix','△Sc','δ','VA',]
print(train[Y5].shape)
print(train[X5].shape)
traindata_x1,valdata_x1,traindata_y1,valdata_y1=train_test_split(train[X1],train[Y1],test_size=0.25)
print(traindata_x1.shape)
print(valdata_x1.shape)
traindata_x2,valdata_x2,traindata_y2,valdata_y2=train_test_split(train[X2],train[Y2],test_size=0.25)
print(traindata_x2.shape)
print(valdata_x2.shape)
traindata_x3,valdata_x3,traindata_y3,valdata_y3=train_test_split(train[X3],train[Y3],test_size=0.25)
print(traindata_x3.shape)
print(valdata_x3.shape)
traindata_x4,valdata_x4,traindata_y4,valdata_y4=train_test_split(train[X4],train[Y4],test_size=0.25)
print(traindata_x4.shape)
print(valdata_x4.shape)
traindata_x5,valdata_x5,traindata_y5,valdata_y5=train_test_split(train[X5],train[Y5],test_size=0.25)
print(traindata_x5.shape)
print(valdata_x5.shape)
#DT ALGORITHM
DT1=tree.DecisionTreeClassifier()
DT1=DT1.fit(traindata_x1,traindata_y1)
#print(DT1.feature_importances_)
DT2=tree.DecisionTreeClassifier()
DT2=DT2.fit(traindata_x2,traindata_y2)
#print(DT2.feature_importances_)
DT3=tree.DecisionTreeClassifier()
DT3=DT3.fit(traindata_x3,traindata_y3)
#print(DT3.feature_importances_)
DT4=tree.DecisionTreeClassifier()
DT4=DT4.fit(traindata_x4,traindata_y4)
print(DT4.feature_importances_)
DT5=tree.DecisionTreeClassifier()
DT5=DT5.fit(traindata_x5,traindata_y5)
print(DT5.feature_importances_)
valdatapre_y1_1=DT1.predict(valdata_x1)
print(metrics.accuracy_score(valdata_y1,valdatapre_y1_1))
print(metrics.classification_report(valdata_y1,valdatapre_y1_1))
valdatapre_y2_1=DT2.predict(valdata_x2)
print(metrics.accuracy_score(valdata_y2,valdatapre_y2_1))
print(metrics.classification_report(valdata_y2,valdatapre_y2_1))
valdatapre_y3_1=DT3.predict(valdata_x3)
print(metrics.accuracy_score(valdata_y3,valdatapre_y3_1))
print(metrics.classification_report(valdata_y3,valdatapre_y3_1))
valdatapre_y4_1=DT4.predict(valdata_x4)
print(metrics.accuracy_score(valdata_y4,valdatapre_y4_1))
print(metrics.classification_report(valdata_y4,valdatapre_y4_1))
valdatapre_y5_1=DT5.predict(valdata_x5)
print(metrics.accuracy_score(valdata_y5,valdatapre_y5_1))
print(metrics.classification_report(valdata_y5,valdatapre_y5_1))
#PLOT ROC CURVE
valdatapre_y1_1=DT1.predict(valdata_x1)
valdatay__proba1=DT1.predict_proba(valdata_x1)[:,1]
fpr_DT1,tpr_DT1,thr =metrics.roc_curve(valdata_y1,valdatay__proba1, pos_label=1)
auc=metrics.auc(fpr_DT1,tpr_DT1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT1,tpr_DT1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
valdatapre_y2_1=DT2.predict(valdata_x2)
valdatay__proba2=DT2.predict_proba(valdata_x2)[:,1]
fpr_DT2,tpr_DT2,thr =metrics.roc_curve(valdata_y2,valdatay__proba2, pos_label=1)
auc=metrics.auc(fpr_DT2,tpr_DT2)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT2,tpr_DT2,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT2 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
valdatapre_y3_1=DT3.predict(valdata_x3)
valdatay__proba3=DT3.predict_proba(valdata_x3)[:,1]
fpr_DT3,tpr_DT3,thr =metrics.roc_curve(valdata_y3,valdatay__proba3, pos_label=1)
auc=metrics.auc(fpr_DT3,tpr_DT3)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT3,tpr_DT3,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT3 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
valdatapre_y4_1=DT4.predict(valdata_x4)
valdatay__proba4=DT4.predict_proba(valdata_x4)[:,1]
fpr_DT4,tpr_DT4,thr =metrics.roc_curve(valdata_y4,valdatay__proba4, pos_label=1)
auc=metrics.auc(fpr_DT4,tpr_DT4)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT4,tpr_DT4,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT4 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
valdatapre_y5_1=DT5.predict(valdata_x5)
valdatay__proba5=DT5.predict_proba(valdata_x5)[:,1]
fpr_DT5,tpr_DT5,thr =metrics.roc_curve(valdata_y5,valdatay__proba5, pos_label=1)
auc=metrics.auc(fpr_DT5,tpr_DT5)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT5,tpr_DT5,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT5 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()

#GridSearchCV
from sklearn.model_selection import GridSearchCV
d_tree=tree.DecisionTreeClassifier()
parameters={'criterion': ['entropy','gini'],'max_depth': [3,5,7,10,12,15,20,22,25]}
DT1_GridSearch=GridSearchCV(d_tree,parameters,cv=5)
DT2_GridSearch=GridSearchCV(d_tree,parameters,cv=5)
DT3_GridSearch=GridSearchCV(d_tree,parameters,cv=5)
DT4_GridSearch=GridSearchCV(d_tree,parameters,cv=5)
DT5_GridSearch=GridSearchCV(d_tree,parameters,cv=5)
print(DT1_GridSearch.fit(traindata_x1,traindata_y1))
print(DT2_GridSearch.fit(traindata_x2,traindata_y2))
print(DT3_GridSearch.fit(traindata_x3,traindata_y3))
print(DT4_GridSearch.fit(traindata_x4,traindata_y4))
print(DT5_GridSearch.fit(traindata_x5,traindata_y5))
print("best_params：",DT1_GridSearch.best_params_)
print("best_score：",DT1_GridSearch.best_score_)
print("best_estimator：",DT1_GridSearch.best_estimator_)
print("best_params：",DT2_GridSearch.best_params_)
print("best_score：",DT2_GridSearch.best_score_)
print("best_estimator：",DT2_GridSearch.best_estimator_)
print("best_params：",DT3_GridSearch.best_params_)
print("best_score：",DT3_GridSearch.best_score_)
print("best_estimator：",DT3_GridSearch.best_estimator_)
print("best_params：",DT4_GridSearch.best_params_)
print("best_score：",DT4_GridSearch.best_score_)
print("best_estimator：",DT4_GridSearch.best_estimator_)
print("best_params：",DT5_GridSearch.best_params_)
print("best_score：",DT5_GridSearch.best_score_)
print("best_estimator：",DT5_GridSearch.best_estimator_)
#RETRAINING WITH TUNED PARAMETES 
DT1_1=tree.DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_depth=25,random_state=1)
DT1_1=DT1_1.fit(train[X1],train[Y1])
DT2_1=tree.DecisionTreeClassifier(class_weight='balanced',criterion='entropy',max_depth=15,random_state=1)
DT2_1=DT2_1.fit(train[X2],train[Y2])
DT3_1=tree.DecisionTreeClassifier(class_weight='balanced',criterion='entropy',max_depth=20,random_state=1)
DT3_1=DT3_1.fit(train[X3],train[Y3])
DT4_1=tree.DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_depth=12,random_state=1)
DT4_1=DT4_1.fit(train[X4],train[Y4])
DT5_1=tree.DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_depth=20,random_state=1)
DT5_1=DT5_1.fit(train[X5],train[Y5])
test_y_pre1_2=DT1_1.predict(test[X1])
print(metrics.accuracy_score(test[Y1],test_y_pre1_2))
print(metrics.classification_report(test[Y1],test_y_pre1_2))
test_y_pre2_2=DT2_1.predict(test[X2])
print(metrics.accuracy_score(test[Y2],test_y_pre2_2))
print(metrics.classification_report(test[Y2],test_y_pre2_2))
test_y_pre3_2=DT3_1.predict(test[X3])
print(metrics.accuracy_score(test[Y3],test_y_pre3_2))
print(metrics.classification_report(test[Y3],test_y_pre3_2))
test_y_pre4_2=DT4_1.predict(test[X4])
print(metrics.accuracy_score(test[Y4],test_y_pre4_2))
print(metrics.classification_report(test[Y4],test_y_pre4_2))
test_y_pre5_2=DT5_1.predict(test[X5])
print(metrics.accuracy_score(test[Y5],test_y_pre5_2))
print(metrics.classification_report(test[Y5],test_y_pre5_2))
#PLOT ROC CURVE
test_y_pre1_2=DT1_1.predict(test[X1])
testy__proba1_2=DT1_1.predict_proba(test[X1])[:,1]
fpr_DT1_1,tpr_DT1_1,thr =metrics.roc_curve(test[Y1],testy__proba1_2, pos_label=1)
auc=metrics.auc(fpr_DT1_1,tpr_DT1_1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT1_1,tpr_DT1_1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT1_1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
test_y_pre2_2=DT2_1.predict(test[X2])
testy__proba2_2=DT2_1.predict_proba(test[X2])[:,1]
fpr_DT2_1,tpr_DT2_1,thr =metrics.roc_curve(test[Y2],testy__proba2_2, pos_label=1)
auc=metrics.auc(fpr_DT2_1,tpr_DT2_1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT2_1,tpr_DT2_1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT2_1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
test_y_pre3_2=DT3_1.predict(test[X3])
testy__proba3_2=DT3_1.predict_proba(test[X3])[:,1]
fpr_DT3_1,tpr_DT3_1,thr =metrics.roc_curve(test[Y3],testy__proba3_2, pos_label=1)
auc=metrics.auc(fpr_DT3_1,tpr_DT3_1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT3_1,tpr_DT3_1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT3_1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
test_y_pre4_2=DT4_1.predict(test[X4])
testy__proba4_2=DT4_1.predict_proba(test[X4])[:,1]
fpr_DT4_1,tpr_DT4_1,thr =metrics.roc_curve(test[Y4],testy__proba4_2, pos_label=1)
auc=metrics.auc(fpr_DT4_1,tpr_DT4_1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT4_1,tpr_DT4_1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT4_1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
test_y_pre5_2=DT5_1.predict(test[X5])
testy__proba5_2=DT5_1.predict_proba(test[X5])[:,1]
fpr_DT5_1,tpr_DT5_1,thr =metrics.roc_curve(test[Y5],testy__proba5_2, pos_label=1)
auc=metrics.auc(fpr_DT5_1,tpr_DT5_1)
plt.figure(figsize=(6,6))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr_DT5_1,tpr_DT5_1,"r",linewidth=1.5)
plt.xlabel("False Positive Rate",fontsize=15)
plt.ylabel("True Positive Rate",fontsize=15)
plt.xlim(0,1)
plt.ylim(0,1)
plt.title("DT5_1 ROC curve",fontsize=15)
plt.text(0.2,0.8,"auc="+str(round(auc,4)),fontsize=15)
plt.show()
